# %%
from selenium import webdriver

# %%
from bs4 import BeautifulSoup

# %%
import time

# %%
import datetime as dt

# %%
import pandas as pd

# %%
import re

# %%
keyword='종로구'
startdate=dt.date(year=2021, month=3, day=29)
untildate=startdate+dt.timedelta(days=1)

# %%
path="/Users/dgun/Downloads/Chromedriver"
browser=webdriver.Chrome(path)
language="ko"

# %%
url='https://twitter.com/search?l='+language+'&q='+keyword+'%20since%3A'+str(startdate)+'%20until%3A'+str(untildate)
browser.get(url)
time.sleep(1)

# %%
html=browser.page_source
soup=BeautifulSoup(html,'html.parser')

# %%
contents=soup.find_all("div",{
    "class":"css-901oao r-1fmj7o5 r-1qd0xha r-a023e6 r-16dba41 r-rjixqe r-bcqeeo r-bnwqim r-qvutc0"})

# %%
cleaner=re.compile('<.*?>')
unicode_list=re.compile(r"'[\\u]%d{4,5}'")
tw=[]
for t in contents:
    t=re.sub(cleaner,"",str(t))
    t=re.sub(unicode_list,"",t)
    tw.append(t)
dates=[startdate]*len(tw)

# %%
daily_df=pd.DataFrame({"date":dates, "contents": tw})

# %%
daily_df=daily_df.reset_index(drop=True)
daily_df.to_excel("dg.xlsx", index=False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-21-8de6b5164a54> in <module>
#       1 daily_df=daily_df.reset_index(drop=True)
# ----> 2 daily_df.to_excel("dg.xlsx", index=False)
#
# ~/miniforge3/envs/tf/lib/python3.8/site-packages/pandas-1.3.0.dev0+1197.g244db519fa-py3.8-macosx-11.0-arm64.egg/pandas/core/generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2295             inf_rep=inf_rep,
#    2296         )
# -> 2297         formatter.write(
#    2298             excel_writer,
#    2299             sheet_name=sheet_name,
#
# ~/miniforge3/envs/tf/lib/python3.8/site-packages/pandas-1.3.0.dev0+1197.g244db519fa-py3.8-macosx-11.0-arm64.egg/pandas/io/formats/excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     836             # error: Cannot instantiate abstract class 'ExcelWriter' with abstract
#     837             # attributes 'engine', 'save', 'supported_extensions' and 'write_cells'
# --> 838             writer = ExcelWriter(  # type: ignore[abstract]
#     839                 writer, engine=engine, storage_options=storage_options
#     840             )
#
# ~/miniforge3/envs/tf/lib/python3.8/site-packages/pandas-1.3.0.dev0+1197.g244db519fa-py3.8-macosx-11.0-arm64.egg/pandas/io/excel/_openpyxl.py in __init__(self, path, engine, date_format, datetime_format, mode, storage_options, engine_kwargs)
#      44     ):
#      45         # Use the openpyxl module as the Excel writer.
# ---> 46         from openpyxl.workbook import Workbook
#      47
#      48         super().__init__(
#
# ModuleNotFoundError: No module named 'openpyxl'
