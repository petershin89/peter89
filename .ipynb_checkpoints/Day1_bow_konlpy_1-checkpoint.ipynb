# %%
from hello import say_hello
# Out:
# -------------------------------------------------------------------
# ModuleNotFoundError               Traceback (most recent call last)
# <ipython-input-5-57ffdbe682a4> in <module>
# ----> 1 from hello import say_hello
#
# ModuleNotFoundError: No module named 'hello'

# %%
import sys
sys.path
# Out:
# ['/Users/dgun/Desktop/GitHub',
#  '/Users/dgun/miniforge3/envs/tf/lib/python38.zip',
#  '/Users/dgun/miniforge3/envs/tf/lib/python3.8',
#  '/Users/dgun/miniforge3/envs/tf/lib/python3.8/lib-dynload',
#  '',
#  '/Users/dgun/miniforge3/envs/tf/lib/python3.8/site-packages',
#  '/Users/dgun/miniforge3/envs/tf/lib/python3.8/site-packages/IPython/extensions',
#  '/Users/dgun/.ipython']
