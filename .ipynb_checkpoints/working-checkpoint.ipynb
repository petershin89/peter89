# %%
import sys

# %%
sys.path.append('/Users/dgun/Desktop/GitHub')

# %%
import hello.ipynb
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-fa9b6e3bec50> in <module>
# ----> 1 import hello.ipynb
#
# ~/Desktop/GitHub/hello.py in <module>
#       3   {
#       4    "cell_type": "code",
# ----> 5    "execution_count": null,
#       6    "id": "empirical-marketplace",
#       7    "metadata": {},
#
# NameError: name 'null' is not defined
